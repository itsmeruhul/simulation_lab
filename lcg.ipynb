# %%
a=5
c=3
m=16
z_0=7
u=[]
z=[7]
for i in range (1,50):
  new_z=(5*z[i-1]+3)%16
  z.append(new_z)
  new_u=new_z/16
  u.append(new_u)

print(z)
print(u)

pal.bar
# Out:
# [7, 6, 1, 8, 11, 10, 5, 12, 15, 14, 9, 0, 3, 2, 13, 4, 7, 6, 1, 8, 11, 10, 5, 12, 15, 14, 9, 0, 3, 2, 13, 4, 7, 6, 1, 8, 11, 10, 5, 12, 15, 14, 9, 0, 3, 2, 13, 4, 7, 6]
# [0.375, 0.0625, 0.5, 0.6875, 0.625, 0.3125, 0.75, 0.9375, 0.875, 0.5625, 0.0, 0.1875, 0.125, 0.8125, 0.25, 0.4375, 0.375, 0.0625, 0.5, 0.6875, 0.625, 0.3125, 0.75, 0.9375, 0.875, 0.5625, 0.0, 0.1875, 0.125, 0.8125, 0.25, 0.4375, 0.375, 0.0625, 0.5, 0.6875, 0.625, 0.3125, 0.75, 0.9375, 0.875, 0.5625, 0.0, 0.1875, 0.125, 0.8125, 0.25, 0.4375, 0.375]

# %%
z=[3,5]
u=[5/12]
for i in range(2,10):
  new_z=(z[i-1]+2*(z[i-2])**2)%12
  z.append(new_z)
  new_u=new_z/12
  u.append(new_u)

print(z)
print(u)
# Out:
# [3, 5, 11, 1, 3, 5, 11, 1, 3, 5]
# [0.4166666666666667, 0.9166666666666666, 0.08333333333333333, 0.25, 0.4166666666666667, 0.9166666666666666, 0.08333333333333333, 0.25, 0.4166666666666667]

# %%
z_1=[7]
u=[]
z_2=[3,5]
z=[]
for i in range(1,10):
  new_z_1=(3*(z_1[i-1])**2+5)%16
  z_1.append(new_z_1)

for i in range(2,10):
  new_z_2=(z_2[i-1]+2*(z_2[i-2])**2)%12
  z_2.append(new_z_2) 

for i in range(1,10):
  z_new=(z_1[i]+(z_2[i])**2)%16
  z.append(z_new)



  


print(z)
print(u)
# Out:
# [1, 14, 1, 14, 9, 14, 1, 14, 9]
# []
