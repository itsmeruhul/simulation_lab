# %%
a=int(input("enter a number "))
for i in range(a+1):
  for j in range(i):
    print("*",end='')
  print("\n")

for i in range(a-1,-1,-1):
  for j in range(i):
    print("*",end='')
  print("\n")
