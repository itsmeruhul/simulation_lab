# %%
import random 
import math

# %%
n=[100,1000,5000]
a=0
b=5
 
for trials in n:
  #For line-1
  a=0
  b=1
  func1_sum=0
  func1_square_sum=0
  for i in range(trials):
    #randomly pick a value of x between a and b
    #find f1(x) value
    #func1_sum update
    #func_squared1_sum update
  
  func1_average=
  func_squared1_average=
  integral_value1=
  error1=
  print("For number of points= ", trials)
  print("Integral valu1: ",integral_value1)
  print("Error1:", error1)
 
  #line 2:
  a=1
  b=2
  func2_sum=0
  func2_square_sum=0
  for i in range(trials):
    #randomly pick a value of x between a and b
    #find f(x) value
    #func1_sum update
    #func_squared1_sum update
  
  func2_average=
  func_squared2_average=
  integral_value2=
  error2=
  final_area= integral_value1+integral_value2
  print("For number of points= ", trials)
  print("Integral value: ",integral_value)
  print("Error:", error)
#Bar chart: x-axis: n , y-axis: error
