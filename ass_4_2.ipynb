# %%
import random 
import math

# %%
n=[100,1000,5000,10000]
a_1=0
b_1=4
a_2=4
b_2=8
for i in range(len(n)):
  func_1_sum=0
  func_1_sq_sum=0
  fnnc_1_sq=0
  func_2_sum=0
  func_2_sq_sum=0
  func_2_sq=0
  for j in range(n[i]):
    x=random.uniform(a_1,b_1)
    func_1=(4*x)**.5
    func_1_sum=func_1_sum+func_1
    func_1_sq=func_1**2
    func_1_sq_sum=func_1_sq+func_1_sq_sum

    x_1=random.uniform(a_2,b_2)
    func_2=8-x_1
    func_2_sum=func_2_sum+func_2
    func_2_sq=func_2**2
    func_2_sq_sum=func_2_sq+func_2_sq_sum

  func_1_br=func_1_sum/n[i] 
  func_2_br=func_2_sum/n[i]

  func_1_sq_sum_br=func_1_sq_sum/n[i]  
  func_2_sq_sum_br=func_2_sq_sum/n[i]  

  inte_value_1=func_1_br*(b_1-a_1) 
  inte_value_2=func_2_br*(b_2-a_2) 

  error_1=((b_1-a_1)/(n[i])**.5)*(func_1_sq_sum_br-(func_1_br)**2)**.5
  error_2=((b_2-a_2)/(n[i])**.5)*(func_2_sq_sum_br-(func_2_br)**2)**.5

  inte_value=inte_value_1+inte_value_2
  error=error_1+error_2
   
  print("n is",n[i])
  print("inte_value =",inte_value)
  print("error =",error)
# Out:
# n is 100
# inte_value = 19.707357353171844
# error = 0.778499951835503
# n is 1000
# inte_value = 18.607349525984077
# error = 0.2671121862025765
# n is 5000
# inte_value = 18.711056836409256
# error = 0.1185533339426946
# n is 10000
# inte_value = 18.56130074214411
# error = 0.08411498885832364
