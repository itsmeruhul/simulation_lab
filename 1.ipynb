# %%
string=str(input("enter a input :"))
print(string)
l=len(string)
print(l)
a = string[0]
a1=string[1:]
print(a)
string = a + a1.replace(a,"$")
print(string)
# Out:
# enter a input :abca
# abca
# 4
# a
# abc$
