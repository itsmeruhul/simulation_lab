# %%
a=int(input("enter start number "))
b=int(input("enter end number "))
prime=[]
for i in range(a,b):
  f=0
  for j in range(2, i):
    if (i % j) == 0:
      f=1
  if f==0:
    if i>1: 
      prime.append(i)
print(prime)
