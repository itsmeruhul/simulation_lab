# %%
listone=[1,2,3,4]
listtwo=[5,6,7,8,9]
listone_1=[]
listtwo_2=[]
listthree=[]
for i in range(1,len(listone),2):
  listone_1.append(listone[i])
for i in range(0,len(listtwo),2):
  listtwo_2.append(listtwo[i])

print(listone_1)
print(listtwo_2)
listthree=listone_1 + listtwo_2
print(listthree)
# Out:
# [2, 4]
# [5, 7, 9]
# [2, 4, 5, 7, 9]
