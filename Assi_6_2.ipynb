# %%
z_1=[12,7]
u_1=[7/16]
z_2=[3,5]
u_2=[5/17]
z_3=[2,7]
u_3=[7/15]
n=[100,1000,10000]
for i in range(len(n)):
  for j in range(2,n[i]):
    new_z_1=(13*z_1[i-1]+11*z_1[i-2]+3)%16
    z_1.append(new_z_1)
    new_u_1=new_z_1/16
    u_1.append(new_u_1)

    new_z_2=(12*z_2[i-1]**2+13*z_2[i-2])%17
    z_2.append(new_z_2)
    new_u_2=new_z_2/17
    u_2.append(new_u_2)

    new_z_3=(z_3[i-1]**3+z_3[i-2]**2)%15
    z_3.append(new_z_3)
    new_u_3=new_z_3/15
    u_3.append(new_u_3)




    
  print(z_1) 
  print(u_1)
  print(z_2) 
  print(u_2)
  print(z_3) 
  print(u_3)
# Out:
# [12, 7, 2, 10, 11, 0, 12, 15, 10, 10, 3, 8, 12, 7, 2, 10, 11, 0, 12, 15, 10, 10, 3, 8, 12, 7, 2, 10, 11, 0, 12, 15, 10, 10, 3, 8, 12, 7, 2, 10, 11, 0, 12, 15, 10, 10, 3, 8, 12, 7, 2, 10, 11, 0, 12, 15, 10, 10, 3, 8, 12, 7, 2, 10, 11, 0, 12, 15, 10, 10, 3, 8, 12, 7, 2, 10, 11, 0, 12, 15, 10, 10, 3, 8, 12, 7, 2, 10, 11, 0, 12, 15, 10, 10, 3, 8, 12, 7, 2, 10]
# ...

# %%
 for j in range(1,10000):
   u=u_1[i]+u_2[i]+u_3[i]
   print(u)
# Out:
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# 1.1982843137254902
# ...
