# %%
my_list = []
print("enter s for stop")
while True: 
  a = input()
  if a=="s":
    break
  else:
    my_list.append(int(a))
print(my_list)
even=0
odd=0
k=0
l = []
for i in range(len(my_list)):
  if my_list[i]%2!=0:
    odd=odd+1
    l.append(my_list[i])
    k=k+1
  else:
    even=even+1
my_list=l
print(even)
print(odd)
print(my_list)
